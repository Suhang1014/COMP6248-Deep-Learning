# %% [markdown]
# # Transfer Learning and Fine Tuning

# %% [markdown]
# __Before starting, we recommend you enable GPU acceleration if you're running on Colab.__

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer

# %% [markdown]
# ## Getting started
#
# Start by downloading and unzipping the data set. The code in the following block will download and unzip the data we're going to use.

# %%
from os.path import exists
if not exists('data'):
    # !wget -O boat-data.zip http://www.southampton.ac.uk/~jsh2/comp6248-lab-data/boat-data.zip
    # !unzip boat-data.zip
# Out:
# --2019-03-20 21:20:32--  http://www.southampton.ac.uk/~jsh2/comp6248-lab-data/boat-data.zip
# Resolving www.southampton.ac.uk (www.southampton.ac.uk)... 152.78.118.52
# Connecting to www.southampton.ac.uk (www.southampton.ac.uk)|152.78.118.52|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 266343621 (254M) [application/zip]
# Saving to: ‘boat-data.zip’
#
# boat-data.zip       100%[===================>] 254.00M   571KB/s    in 7m 12s
#
# 2019-03-20 21:27:44 (603 KB/s) - ‘boat-data.zip’ saved [266343621/266343621]
#
# Archive:  boat-data.zip
#    creating: data/
#    creating: data/valid/
#    creating: data/valid/Gondola/
#   inflating: data/valid/Gondola/20130410_080145_34221.jpg
#    creating: __MACOSX/
#    creating: __MACOSX/data/
#    creating: __MACOSX/data/valid/
#    creating: __MACOSX/data/valid/Gondola/
#   inflating: __MACOSX/data/valid/Gondola/._20130410_080145_34221.jpg
#   inflating: data/valid/Gondola/20130410_092410_53868.jpg
#   inflating: __MACOSX/data/valid/Gondola/._20130410_092410_53868.jpg
#   inflating: data/valid/Gondola/20130305_090134_40900.jpg
#   inflating: __MACOSX/data/valid/Gondola/._20130305_090134_40900.jpg
#   inflating: data/valid/.DS_Store
#   inflating: __MACOSX/data/valid/._.DS_Store
#    creating: data/valid/Topa/
#   inflating: data/valid/Topa/20130305_110519_62348.jpg
#    creating: __MACOSX/data/valid/Topa/
#   inflating: __MACOSX/data/valid/Topa/._20130305_110519_62348.jpg
#   inflating: data/valid/Topa/20130305_105031_59188.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130305_105031_59188.jpg
#   inflating: data/valid/Topa/20130307_145920_00412.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130307_145920_00412.jpg
#   inflating: data/valid/Topa/20130305_082145_34494.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130305_082145_34494.jpg
#   inflating: data/valid/Topa/20130410_142023_10241.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130410_142023_10241.jpg
#   inflating: data/valid/Topa/20130305_151621_98761.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130305_151621_98761.jpg
#   inflating: data/valid/Topa/20130306_073816_20368.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130306_073816_20368.jpg
#   inflating: data/valid/Topa/20130410_103636_67073.jpg
#   inflating: __MACOSX/data/valid/Topa/._20130410_103636_67073.jpg
#    creating: data/valid/Mototopo/
#   inflating: data/valid/Mototopo/20130306_060639_03999.jpg
#    creating: __MACOSX/data/valid/Mototopo/
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_060639_03999.jpg
#   inflating: data/valid/Mototopo/20130305_100321_51489.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_100321_51489.jpg
#   inflating: data/valid/Mototopo/20130304_135405_30431.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_135405_30431.jpg
#   inflating: data/valid/Mototopo/20130305_065518_18667.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_065518_18667.jpg
#   inflating: data/valid/Mototopo/20130305_065207_18243.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_065207_18243.jpg
#   inflating: data/valid/Mototopo/20130306_080711_25130.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_080711_25130.jpg
#   inflating: data/valid/Mototopo/20130306_092536_39311.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_092536_39311.jpg
#   inflating: data/valid/Mototopo/20130306_094930_43283.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_094930_43283.jpg
#   inflating: data/valid/Mototopo/20130307_082120_34713.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_082120_34713.jpg
#   inflating: data/valid/Mototopo/20130305_071320_22213.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_071320_22213.jpg
#   inflating: data/valid/Mototopo/20130307_095339_54623.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_095339_54623.jpg
#   inflating: data/valid/Mototopo/20130304_144313_39259.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_144313_39259.jpg
#   inflating: data/valid/Mototopo/20130305_072840_25200.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_072840_25200.jpg
#   inflating: data/valid/Mototopo/20130307_102017_58927.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_102017_58927.jpg
#   inflating: data/valid/Mototopo/20130304_112956_05755.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_112956_05755.jpg
#   inflating: data/valid/Mototopo/20130304_060045_06051.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_060045_06051.jpg
#   inflating: data/valid/Mototopo/20130304_082736_34604.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_082736_34604.jpg
#   inflating: data/valid/Mototopo/20130306_100746_46166.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_100746_46166.jpg
#   inflating: data/valid/Mototopo/20130305_083316_36650.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_083316_36650.jpg
#   inflating: data/valid/Mototopo/20130304_133012_26651.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_133012_26651.jpg
#   inflating: data/valid/Mototopo/20130305_102558_55167.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_102558_55167.jpg
#   inflating: data/valid/Mototopo/20130305_113811_67978.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_113811_67978.jpg
#   inflating: data/valid/Mototopo/20130304_110815_01999.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_110815_01999.jpg
#   inflating: data/valid/Mototopo/20130305_070230_20067.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_070230_20067.jpg
#   inflating: data/valid/Mototopo/20130304_122411_15967.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_122411_15967.jpg
#   inflating: data/valid/Mototopo/20130305_162922_08325.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_162922_08325.jpg
#   inflating: data/valid/Mototopo/20130305_091452_43617.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_091452_43617.jpg
#   inflating: data/valid/Mototopo/20130307_063452_12679.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_063452_12679.jpg
#   inflating: data/valid/Mototopo/20130306_060005_02581.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_060005_02581.jpg
#   inflating: data/valid/Mototopo/20130306_071339_15764.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_071339_15764.jpg
#   inflating: data/valid/Mototopo/20130304_082820_34556.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_082820_34556.jpg
#   inflating: data/valid/Mototopo/20130304_150531_43048.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_150531_43048.jpg
#   inflating: data/valid/Mototopo/20130305_065912_19421.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_065912_19421.jpg
#   inflating: data/valid/Mototopo/20130307_062432_11237.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_062432_11237.jpg
#   inflating: data/valid/Mototopo/20130306_071816_16722.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_071816_16722.jpg
#   inflating: data/valid/Mototopo/20130306_081659_26693.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_081659_26693.jpg
#   inflating: data/valid/Mototopo/20130306_082736_28255.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_082736_28255.jpg
#   inflating: data/valid/Mototopo/20130304_081941_32665.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_081941_32665.jpg
#   inflating: data/valid/Mototopo/20130305_084949_39547.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_084949_39547.jpg
#   inflating: data/valid/Mototopo/20130305_150058_96731.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_150058_96731.jpg
#   inflating: data/valid/Mototopo/20130306_071434_16053.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_071434_16053.jpg
#   inflating: data/valid/Mototopo/20130305_075746_31042.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_075746_31042.jpg
#   inflating: data/valid/Mototopo/20130305_105548_60409.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_105548_60409.jpg
#   inflating: data/valid/Mototopo/20130305_111738_64983.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_111738_64983.jpg
#   inflating: data/valid/Mototopo/20130304_065821_16662.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_065821_16662.jpg
#   inflating: data/valid/Mototopo/20130305_093124_45776.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_093124_45776.jpg
#   inflating: data/valid/Mototopo/20130307_075821_30461.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_075821_30461.jpg
#   inflating: data/valid/Mototopo/20130306_062116_05973.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_062116_05973.jpg
#   inflating: data/valid/Mototopo/20130306_110922_55605.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_110922_55605.jpg
#   inflating: data/valid/Mototopo/20130307_083349_36851.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_083349_36851.jpg
#   inflating: data/valid/Mototopo/20130307_065257_16069.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_065257_16069.jpg
#   inflating: data/valid/Mototopo/20130307_073545_25517.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_073545_25517.jpg
#   inflating: data/valid/Mototopo/20130304_112749_05518.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_112749_05518.jpg
#   inflating: data/valid/Mototopo/20130307_112840_71302.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_112840_71302.jpg
#   inflating: data/valid/Mototopo/20130305_130401_80402.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_130401_80402.jpg
#   inflating: data/valid/Mototopo/20130304_131446_24092.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_131446_24092.jpg
#   inflating: data/valid/Mototopo/20130305_111843_65125.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_111843_65125.jpg
#   inflating: data/valid/Mototopo/20130307_083805_37618.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_083805_37618.jpg
#   inflating: data/valid/Mototopo/20130305_055445_07791.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_055445_07791.jpg
#   inflating: data/valid/Mototopo/20130306_085215_33161.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_085215_33161.jpg
#   inflating: data/valid/Mototopo/20130306_075939_24079.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_075939_24079.jpg
#   inflating: data/valid/Mototopo/20130307_064626_14956.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_064626_14956.jpg
#   inflating: data/valid/Mototopo/20130305_133803_84377.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_133803_84377.jpg
#   inflating: data/valid/Mototopo/20130410_070058_22031.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130410_070058_22031.jpg
#   inflating: data/valid/Mototopo/20130307_144548_98195.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_144548_98195.jpg
#   inflating: data/valid/Mototopo/20130307_113617_72824.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_113617_72824.jpg
#   inflating: data/valid/Mototopo/20130306_130044_70796.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_130044_70796.jpg
#   inflating: data/valid/Mototopo/20130305_092846_45407.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_092846_45407.jpg
#   inflating: data/valid/Mototopo/20130305_103137_56027.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_103137_56027.jpg
#   inflating: data/valid/Mototopo/20130307_083916_37674.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_083916_37674.jpg
#   inflating: data/valid/Mototopo/20130305_115721_71275.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_115721_71275.jpg
#   inflating: data/valid/Mototopo/20130307_065434_16527.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_065434_16527.jpg
#   inflating: data/valid/Mototopo/20130307_074449_27635.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_074449_27635.jpg
#   inflating: data/valid/Mototopo/20130307_153338_05108.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_153338_05108.jpg
#   inflating: data/valid/Mototopo/20130304_072052_21316.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_072052_21316.jpg
#   inflating: data/valid/Mototopo/20130306_130727_71719.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_130727_71719.jpg
#   inflating: data/valid/Mototopo/20130306_102653_49558.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_102653_49558.jpg
#   inflating: data/valid/Mototopo/20130304_083621_36350.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_083621_36350.jpg
#   inflating: data/valid/Mototopo/20130304_084010_36987.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_084010_36987.jpg
#   inflating: data/valid/Mototopo/20130306_111919_56763.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130306_111919_56763.jpg
#   inflating: data/valid/Mototopo/20130307_100545_56569.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_100545_56569.jpg
#   inflating: data/valid/Mototopo/20130307_112001_70008.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130307_112001_70008.jpg
#   inflating: data/valid/Mototopo/20130305_100112_51107.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_100112_51107.jpg
#   inflating: data/valid/Mototopo/20130304_152900_46665.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_152900_46665.jpg
#   inflating: data/valid/Mototopo/20130305_135050_85654.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_135050_85654.jpg
#   inflating: data/valid/Mototopo/20130305_130254_80208.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_130254_80208.jpg
#   inflating: data/valid/Mototopo/20130305_112555_66335.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130305_112555_66335.jpg
#   inflating: data/valid/Mototopo/20130304_065716_16544.jpg
#   inflating: __MACOSX/data/valid/Mototopo/._20130304_065716_16544.jpg
#    creating: data/valid/Water/
#   inflating: data/valid/Water/20130306_090805_36446.jpg
#    creating: __MACOSX/data/valid/Water/
#   inflating: __MACOSX/data/valid/Water/._20130306_090805_36446.jpg
#   inflating: data/valid/Water/20130304_084636_38418.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_084636_38418.jpg
#   inflating: data/valid/Water/20130306_070745_14879.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_070745_14879.jpg
#   inflating: data/valid/Water/20130307_110407_67531.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_110407_67531.jpg
#   inflating: data/valid/Water/20130304_063554_11439.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_063554_11439.jpg
#   inflating: data/valid/Water/20130305_140858_89962.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_140858_89962.jpg
#   inflating: data/valid/Water/20130307_102937_60563.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_102937_60563.jpg
#   inflating: data/valid/Water/20130307_140634_93261.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_140634_93261.jpg
#   inflating: data/valid/Water/20130305_073422_26142.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_073422_26142.jpg
#   inflating: data/valid/Water/20130306_121132_64076.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_121132_64076.jpg
#   inflating: data/valid/Water/20130305_061003_10089.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_061003_10089.jpg
#   inflating: data/valid/Water/20130306_160726_95148.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_160726_95148.jpg
#   inflating: data/valid/Water/20130306_105008_53146.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_105008_53146.jpg
#   inflating: data/valid/Water/20130305_090203_41100.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_090203_41100.jpg
#   inflating: data/valid/Water/20130305_071420_22421.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_071420_22421.jpg
#   inflating: data/valid/Water/20130307_094140_51402.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_094140_51402.jpg
#   inflating: data/valid/Water/20130304_073145_23381.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_073145_23381.jpg
#   inflating: data/valid/Water/20130305_144537_94840.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_144537_94840.jpg
#   inflating: data/valid/Water/20130305_091854_44041.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_091854_44041.jpg
#   inflating: data/valid/Water/20130306_082832_28398.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_082832_28398.jpg
#   inflating: data/valid/Water/20130307_062256_11052.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_062256_11052.jpg
#   inflating: data/valid/Water/20130307_094659_52846.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_094659_52846.jpg
#   inflating: data/valid/Water/20130304_061417_08056.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_061417_08056.jpg
#   inflating: data/valid/Water/20130306_073149_18810.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_073149_18810.jpg
#   inflating: data/valid/Water/20130304_125526_21353.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_125526_21353.jpg
#   inflating: data/valid/Water/20130306_104109_51666.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_104109_51666.jpg
#   inflating: data/valid/Water/20130306_124510_68899.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_124510_68899.jpg
#   inflating: data/valid/Water/20130306_084312_31762.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_084312_31762.jpg
#   inflating: data/valid/Water/20130304_170311_60105.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_170311_60105.jpg
#   inflating: data/valid/Water/20130304_162042_54394.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_162042_54394.jpg
#   inflating: data/valid/Water/20130305_080816_32584.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_080816_32584.jpg
#   inflating: data/valid/Water/20130304_154528_49142.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_154528_49142.jpg
#   inflating: data/valid/Water/20130307_144422_97948.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_144422_97948.jpg
#   inflating: data/valid/Water/20130304_112034_04138.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_112034_04138.jpg
#   inflating: data/valid/Water/20130304_064903_14225.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_064903_14225.jpg
#   inflating: data/valid/Water/20130307_111111_68815.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_111111_68815.jpg
#   inflating: data/valid/Water/20130304_150537_43072.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_150537_43072.jpg
#   inflating: data/valid/Water/20130306_141336_79588.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_141336_79588.jpg
#   inflating: data/valid/Water/20130306_162344_97099.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_162344_97099.jpg
#   inflating: data/valid/Water/20130305_152524_99950.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_152524_99950.jpg
#   inflating: data/valid/Water/20130306_084653_32507.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_084653_32507.jpg
#   inflating: data/valid/Water/20130304_070551_18249.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_070551_18249.jpg
#   inflating: data/valid/Water/20130305_072103_23664.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_072103_23664.jpg
#   inflating: data/valid/Water/20130304_160634_51543.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_160634_51543.jpg
#   inflating: data/valid/Water/20130305_092021_44238.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_092021_44238.jpg
#   inflating: data/valid/Water/20130305_130833_81002.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_130833_81002.jpg
#   inflating: data/valid/Water/20130307_145131_99040.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_145131_99040.jpg
#   inflating: data/valid/Water/20130305_120556_72473.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_120556_72473.jpg
#   inflating: data/valid/Water/20130307_084539_39392.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_084539_39392.jpg
#   inflating: data/valid/Water/20130307_071313_20600.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_071313_20600.jpg
#   inflating: data/valid/Water/20130307_065924_17700.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_065924_17700.jpg
#   inflating: data/valid/Water/20130305_122905_76782.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_122905_76782.jpg
#   inflating: data/valid/Water/20130305_085139_39961.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_085139_39961.jpg
#   inflating: data/valid/Water/20130305_092547_45121.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_092547_45121.jpg
#   inflating: data/valid/Water/20130307_063340_12534.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_063340_12534.jpg
#   inflating: data/valid/Water/20130306_090230_35396.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_090230_35396.jpg
#   inflating: data/valid/Water/20130304_133111_27090.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_133111_27090.jpg
#   inflating: data/valid/Water/20130304_160744_51596.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_160744_51596.jpg
#   inflating: data/valid/Water/20130305_080035_31518.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_080035_31518.jpg
#   inflating: data/valid/Water/20130305_060648_09636.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_060648_09636.jpg
#   inflating: data/valid/Water/20130304_140416_32387.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_140416_32387.jpg
#   inflating: data/valid/Water/20130305_080313_32006.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_080313_32006.jpg
#   inflating: data/valid/Water/20130306_091210_37086.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_091210_37086.jpg
#   inflating: data/valid/Water/20130304_065725_16534.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_065725_16534.jpg
#   inflating: data/valid/Water/20130304_145306_40967.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_145306_40967.jpg
#   inflating: data/valid/Water/20130307_110708_68306.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_110708_68306.jpg
#   inflating: data/valid/Water/20130304_145730_41843.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_145730_41843.jpg
#   inflating: data/valid/Water/20130306_124706_69345.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_124706_69345.jpg
#   inflating: data/valid/Water/20130304_160825_51908.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_160825_51908.jpg
#   inflating: data/valid/Water/20130305_065112_17791.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_065112_17791.jpg
#   inflating: data/valid/Water/20130304_063417_11210.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_063417_11210.jpg
#   inflating: data/valid/Water/20130307_075253_29503.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_075253_29503.jpg
#   inflating: data/valid/Water/20130307_103343_61350.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_103343_61350.jpg
#   inflating: data/valid/Water/20130305_161006_05862.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_161006_05862.jpg
#   inflating: data/valid/Water/20130305_125152_79186.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_125152_79186.jpg
#   inflating: data/valid/Water/20130304_153525_47842.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_153525_47842.jpg
#   inflating: data/valid/Water/20130304_143315_36821.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_143315_36821.jpg
#   inflating: data/valid/Water/20130304_072323_21822.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_072323_21822.jpg
#   inflating: data/valid/Water/20130307_104750_64036.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_104750_64036.jpg
#   inflating: data/valid/Water/20130304_125042_20731.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_125042_20731.jpg
#   inflating: data/valid/Water/20130305_054659_06564.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_054659_06564.jpg
#   inflating: data/valid/Water/20130305_111002_63815.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_111002_63815.jpg
#   inflating: data/valid/Water/20130306_144711_83773.jpg
#   inflating: __MACOSX/data/valid/Water/._20130306_144711_83773.jpg
#   inflating: data/valid/Water/20130307_110017_66960.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_110017_66960.jpg
#   inflating: data/valid/Water/20130307_093155_49757.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_093155_49757.jpg
#   inflating: data/valid/Water/20130304_111253_02571.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_111253_02571.jpg
#   inflating: data/valid/Water/20130304_114114_07693.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_114114_07693.jpg
#   inflating: data/valid/Water/20130304_132244_25676.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_132244_25676.jpg
#   inflating: data/valid/Water/20130304_115139_09747.jpg
#   inflating: __MACOSX/data/valid/Water/._20130304_115139_09747.jpg
#   inflating: data/valid/Water/20130305_075301_30412.jpg
#   inflating: __MACOSX/data/valid/Water/._20130305_075301_30412.jpg
#   inflating: data/valid/Water/20130307_143636_97068.jpg
#   inflating: __MACOSX/data/valid/Water/._20130307_143636_97068.jpg
#    creating: data/valid/Ambulanza/
#   inflating: data/valid/Ambulanza/20130305_092025_44192.jpg
#    creating: __MACOSX/data/valid/Ambulanza/
#   inflating: __MACOSX/data/valid/Ambulanza/._20130305_092025_44192.jpg
#   inflating: data/valid/Ambulanza/20130306_100411_45769.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130306_100411_45769.jpg
#   inflating: data/valid/Ambulanza/20130306_120135_63227.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130306_120135_63227.jpg
#   inflating: data/valid/Ambulanza/20130306_062457_06501.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130306_062457_06501.jpg
#   inflating: data/valid/Ambulanza/20130306_102051_48612.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130306_102051_48612.jpg
#   inflating: data/valid/Ambulanza/20130304_112910_05752.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130304_112910_05752.jpg
#   inflating: data/valid/Ambulanza/20130410_073217_28382.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130410_073217_28382.jpg
#   inflating: data/valid/Ambulanza/20130410_132153_99016.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130410_132153_99016.jpg
#   inflating: data/valid/Ambulanza/20130304_112732_05480.jpg
#   inflating: __MACOSX/data/valid/Ambulanza/._20130304_112732_05480.jpg
#    creating: data/valid/Lanciafino10m/
#   inflating: data/valid/Lanciafino10m/20130307_131019_85372.jpg
#    creating: __MACOSX/data/valid/Lanciafino10m/
#   inflating: __MACOSX/data/valid/Lanciafino10m/._20130307_131019_85372.jpg
#   inflating: data/valid/Lanciafino10m/20130307_124717_82280.jpg
#   inflating: __MACOSX/data/valid/Lanciafino10m/._20130307_124717_82280.jpg
#   inflating: data/valid/Lanciafino10m/20130306_125012_69659.jpg
#   inflating: __MACOSX/data/valid/Lanciafino10m/._20130306_125012_69659.jpg
#    creating: data/valid/VaporettoACTV/
#   inflating: data/valid/VaporettoACTV/20130307_082436_35104.jpg
#    creating: __MACOSX/data/valid/VaporettoACTV/
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_082436_35104.jpg
#   inflating: data/valid/VaporettoACTV/20130305_153349_01057.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_153349_01057.jpg
#   inflating: data/valid/VaporettoACTV/20130305_063546_14914.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_063546_14914.jpg
#   inflating: data/valid/VaporettoACTV/20130307_113510_72146.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_113510_72146.jpg
#   inflating: data/valid/VaporettoACTV/20130305_062446_12841.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_062446_12841.jpg
#   inflating: data/valid/VaporettoACTV/20130307_100434_56486.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_100434_56486.jpg
#   inflating: data/valid/VaporettoACTV/20130305_145458_96136.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_145458_96136.jpg
#   inflating: data/valid/VaporettoACTV/20130306_140617_78431.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_140617_78431.jpg
#   inflating: data/valid/VaporettoACTV/20130306_083543_30034.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_083543_30034.jpg
#   inflating: data/valid/VaporettoACTV/20130306_113310_58424.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_113310_58424.jpg
#   inflating: data/valid/VaporettoACTV/20130306_131225_72107.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_131225_72107.jpg
#   inflating: data/valid/VaporettoACTV/20130304_073918_24318.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_073918_24318.jpg
#   inflating: data/valid/VaporettoACTV/20130305_161723_06910.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_161723_06910.jpg
#   inflating: data/valid/VaporettoACTV/20130306_161605_96245.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_161605_96245.jpg
#   inflating: data/valid/VaporettoACTV/20130304_164447_57698.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_164447_57698.jpg
#   inflating: data/valid/VaporettoACTV/20130305_122623_76310.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_122623_76310.jpg
#   inflating: data/valid/VaporettoACTV/20130304_130642_22789.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_130642_22789.jpg
#   inflating: data/valid/VaporettoACTV/20130306_095023_43344.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_095023_43344.jpg
#   inflating: data/valid/VaporettoACTV/20130307_104648_63788.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_104648_63788.jpg
#   inflating: data/valid/VaporettoACTV/20130304_165525_59078.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_165525_59078.jpg
#   inflating: data/valid/VaporettoACTV/20130307_133020_88211.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_133020_88211.jpg
#   inflating: data/valid/VaporettoACTV/20130304_075055_26771.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_075055_26771.jpg
#   inflating: data/valid/VaporettoACTV/20130306_130531_71365.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_130531_71365.jpg
#   inflating: data/valid/VaporettoACTV/20130307_064427_14638.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_064427_14638.jpg
#   inflating: data/valid/VaporettoACTV/20130307_123730_81264.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_123730_81264.jpg
#   inflating: data/valid/VaporettoACTV/20130305_082258_34599.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_082258_34599.jpg
#   inflating: data/valid/VaporettoACTV/20130306_112853_58010.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_112853_58010.jpg
#   inflating: data/valid/VaporettoACTV/20130305_102011_54457.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_102011_54457.jpg
#   inflating: data/valid/VaporettoACTV/20130304_132401_25806.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_132401_25806.jpg
#   inflating: data/valid/VaporettoACTV/20130305_112102_65498.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_112102_65498.jpg
#   inflating: data/valid/VaporettoACTV/20130304_162716_55004.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_162716_55004.jpg
#   inflating: data/valid/VaporettoACTV/20130304_122357_15938.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_122357_15938.jpg
#   inflating: data/valid/VaporettoACTV/20130306_152202_88817.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_152202_88817.jpg
#   inflating: data/valid/VaporettoACTV/20130305_131406_81376.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_131406_81376.jpg
#   inflating: data/valid/VaporettoACTV/20130306_122237_66049.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_122237_66049.jpg
#   inflating: data/valid/VaporettoACTV/20130305_110247_61580.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_110247_61580.jpg
#   inflating: data/valid/VaporettoACTV/20130305_165432_11516.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_165432_11516.jpg
#   inflating: data/valid/VaporettoACTV/20130304_060457_06577.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_060457_06577.jpg
#   inflating: data/valid/VaporettoACTV/20130306_061355_04816.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_061355_04816.jpg
#   inflating: data/valid/VaporettoACTV/20130307_115352_75401.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_115352_75401.jpg
#   inflating: data/valid/VaporettoACTV/20130306_160003_94044.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_160003_94044.jpg
#   inflating: data/valid/VaporettoACTV/20130304_062130_08879.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_062130_08879.jpg
#   inflating: data/valid/VaporettoACTV/20130305_130452_80398.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_130452_80398.jpg
#   inflating: data/valid/VaporettoACTV/20130304_111655_03247.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_111655_03247.jpg
#   inflating: data/valid/VaporettoACTV/20130306_160651_95009.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_160651_95009.jpg
#   inflating: data/valid/VaporettoACTV/20130306_072733_18087.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_072733_18087.jpg
#   inflating: data/valid/VaporettoACTV/20130307_060418_08745.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_060418_08745.jpg
#   inflating: data/valid/VaporettoACTV/20130304_134411_29125.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_134411_29125.jpg
#   inflating: data/valid/VaporettoACTV/20130306_073046_18599.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_073046_18599.jpg
#   inflating: data/valid/VaporettoACTV/20130304_123532_18133.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_123532_18133.jpg
#   inflating: data/valid/VaporettoACTV/20130304_124414_19810.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_124414_19810.jpg
#   inflating: data/valid/VaporettoACTV/20130305_070603_20954.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_070603_20954.jpg
#   inflating: data/valid/VaporettoACTV/20130306_115229_62451.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_115229_62451.jpg
#   inflating: data/valid/VaporettoACTV/20130307_123450_80637.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_123450_80637.jpg
#   inflating: data/valid/VaporettoACTV/20130305_143416_93255.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_143416_93255.jpg
#   inflating: data/valid/VaporettoACTV/20130306_120415_63561.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_120415_63561.jpg
#   inflating: data/valid/VaporettoACTV/20130304_062354_09284.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_062354_09284.jpg
#   inflating: data/valid/VaporettoACTV/20130305_073413_26153.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_073413_26153.jpg
#   inflating: data/valid/VaporettoACTV/20130307_075535_30230.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_075535_30230.jpg
#   inflating: data/valid/VaporettoACTV/20130307_094650_52702.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_094650_52702.jpg
#   inflating: data/valid/VaporettoACTV/20130306_080518_25088.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_080518_25088.jpg
#   inflating: data/valid/VaporettoACTV/20130304_114138_07805.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_114138_07805.jpg
#   inflating: data/valid/VaporettoACTV/20130305_121108_73710.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_121108_73710.jpg
#   inflating: data/valid/VaporettoACTV/20130304_154441_49009.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_154441_49009.jpg
#   inflating: data/valid/VaporettoACTV/20130304_162036_54387.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_162036_54387.jpg
#   inflating: data/valid/VaporettoACTV/20130304_162104_54549.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_162104_54549.jpg
#   inflating: data/valid/VaporettoACTV/20130304_114558_08788.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_114558_08788.jpg
#   inflating: data/valid/VaporettoACTV/20130307_102712_60419.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_102712_60419.jpg
#   inflating: data/valid/VaporettoACTV/20130307_131828_86833.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_131828_86833.jpg
#   inflating: data/valid/VaporettoACTV/20130305_114207_68524.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_114207_68524.jpg
#   inflating: data/valid/VaporettoACTV/20130305_091450_43539.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_091450_43539.jpg
#   inflating: data/valid/VaporettoACTV/20130307_121416_78414.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_121416_78414.jpg
#   inflating: data/valid/VaporettoACTV/20130304_121508_14283.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_121508_14283.jpg
#   inflating: data/valid/VaporettoACTV/20130305_111622_64832.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_111622_64832.jpg
#   inflating: data/valid/VaporettoACTV/20130306_155543_93044.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_155543_93044.jpg
#   inflating: data/valid/VaporettoACTV/20130304_123714_18706.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_123714_18706.jpg
#   inflating: data/valid/VaporettoACTV/20130305_055420_07531.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_055420_07531.jpg
#   inflating: data/valid/VaporettoACTV/20130304_070710_18556.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_070710_18556.jpg
#   inflating: data/valid/VaporettoACTV/20130307_072324_22995.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_072324_22995.jpg
#   inflating: data/valid/VaporettoACTV/20130307_141815_94650.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_141815_94650.jpg
#   inflating: data/valid/VaporettoACTV/20130304_125424_20989.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_125424_20989.jpg
#   inflating: data/valid/VaporettoACTV/20130304_061921_08710.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_061921_08710.jpg
#   inflating: data/valid/VaporettoACTV/20130305_095036_49340.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_095036_49340.jpg
#   inflating: data/valid/VaporettoACTV/20130305_083731_37406.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_083731_37406.jpg
#   inflating: data/valid/VaporettoACTV/20130305_071752_23167.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_071752_23167.jpg
#   inflating: data/valid/VaporettoACTV/20130305_083356_36734.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_083356_36734.jpg
#   inflating: data/valid/VaporettoACTV/20130306_124430_68806.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_124430_68806.jpg
#   inflating: data/valid/VaporettoACTV/20130305_124456_78384.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_124456_78384.jpg
#   inflating: data/valid/VaporettoACTV/20130307_110424_67568.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130307_110424_67568.jpg
#   inflating: data/valid/VaporettoACTV/20130306_164403_00028.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130306_164403_00028.jpg
#   inflating: data/valid/VaporettoACTV/20130304_081414_31359.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_081414_31359.jpg
#   inflating: data/valid/VaporettoACTV/20130305_074940_29857.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_074940_29857.jpg
#   inflating: data/valid/VaporettoACTV/20130304_145517_41525.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_145517_41525.jpg
#   inflating: data/valid/VaporettoACTV/20130305_165625_11621.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130305_165625_11621.jpg
#   inflating: data/valid/VaporettoACTV/20130304_112431_05029.jpg
#   inflating: __MACOSX/data/valid/VaporettoACTV/._20130304_112431_05029.jpg
#    creating: data/valid/MotoscafoACTV/
#   inflating: data/valid/MotoscafoACTV/20130307_110558_67754.jpg
#    creating: __MACOSX/data/valid/MotoscafoACTV/
#   inflating: __MACOSX/data/valid/MotoscafoACTV/._20130307_110558_67754.jpg
#   inflating: data/valid/MotoscafoACTV/20130307_112449_70682.jpg
#   inflating: __MACOSX/data/valid/MotoscafoACTV/._20130307_112449_70682.jpg
#    creating: data/valid/Raccoltarifiuti/
#   inflating: data/valid/Raccoltarifiuti/20130305_070814_21389.jpg
#    creating: __MACOSX/data/valid/Raccoltarifiuti/
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130305_070814_21389.jpg
#   inflating: data/valid/Raccoltarifiuti/20130306_071142_15578.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130306_071142_15578.jpg
#   inflating: data/valid/Raccoltarifiuti/20130307_081209_32956.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130307_081209_32956.jpg
#   inflating: data/valid/Raccoltarifiuti/20130306_131036_71992.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130306_131036_71992.jpg
#   inflating: data/valid/Raccoltarifiuti/20130307_142610_95885.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130307_142610_95885.jpg
#   inflating: data/valid/Raccoltarifiuti/20130410_080759_35849.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130410_080759_35849.jpg
#   inflating: data/valid/Raccoltarifiuti/20130307_070539_18869.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130307_070539_18869.jpg
#   inflating: data/valid/Raccoltarifiuti/20130410_124820_92553.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130410_124820_92553.jpg
#   inflating: data/valid/Raccoltarifiuti/20130307_092904_48962.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130307_092904_48962.jpg
#   inflating: data/valid/Raccoltarifiuti/20130305_101612_53976.jpg
#   inflating: __MACOSX/data/valid/Raccoltarifiuti/._20130305_101612_53976.jpg
#    creating: data/valid/Sandoloaremi/
#   inflating: data/valid/Sandoloaremi/20130410_132431_99625.jpg
#    creating: __MACOSX/data/valid/Sandoloaremi/
#   inflating: __MACOSX/data/valid/Sandoloaremi/._20130410_132431_99625.jpg
#   inflating: data/valid/Sandoloaremi/20130307_101403_58093.jpg
#   inflating: __MACOSX/data/valid/Sandoloaremi/._20130307_101403_58093.jpg
#    creating: data/valid/Polizia/
#   inflating: data/valid/Polizia/20130306_103350_50593.jpg
#    creating: __MACOSX/data/valid/Polizia/
#   inflating: __MACOSX/data/valid/Polizia/._20130306_103350_50593.jpg
#   inflating: data/valid/Polizia/20130305_164454_10415.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130305_164454_10415.jpg
#   inflating: data/valid/Polizia/20130307_074728_28144.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130307_074728_28144.jpg
#   inflating: data/valid/Polizia/20130410_090154_49076.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130410_090154_49076.jpg
#   inflating: data/valid/Polizia/20130304_080413_29664.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130304_080413_29664.jpg
#   inflating: data/valid/Polizia/20130305_091552_43758.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130305_091552_43758.jpg
#   inflating: data/valid/Polizia/20130304_144851_40365.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130304_144851_40365.jpg
#   inflating: data/valid/Polizia/20130305_070431_20552.jpg
#   inflating: __MACOSX/data/valid/Polizia/._20130305_070431_20552.jpg
#    creating: data/valid/Patanella/
#   inflating: data/valid/Patanella/20130305_131850_81868.jpg
#    creating: __MACOSX/data/valid/Patanella/
#   inflating: __MACOSX/data/valid/Patanella/._20130305_131850_81868.jpg
#   inflating: data/valid/Patanella/20130307_080038_31052.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130307_080038_31052.jpg
#   inflating: data/valid/Patanella/20130305_122212_75582.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_122212_75582.jpg
#   inflating: data/valid/Patanella/20130306_103004_49974.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130306_103004_49974.jpg
#   inflating: data/valid/Patanella/20130306_110830_55602.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130306_110830_55602.jpg
#   inflating: data/valid/Patanella/20130305_134818_85530.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_134818_85530.jpg
#   inflating: data/valid/Patanella/20130305_153046_00800.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_153046_00800.jpg
#   inflating: data/valid/Patanella/20130307_132146_87193.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130307_132146_87193.jpg
#   inflating: data/valid/Patanella/20130304_150459_42846.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130304_150459_42846.jpg
#   inflating: data/valid/Patanella/20130306_080829_25497.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130306_080829_25497.jpg
#   inflating: data/valid/Patanella/20130306_104147_51942.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130306_104147_51942.jpg
#   inflating: data/valid/Patanella/20130305_142016_91553.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_142016_91553.jpg
#   inflating: data/valid/Patanella/20130410_090320_49696.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130410_090320_49696.jpg
#   inflating: data/valid/Patanella/20130304_120140_11376.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130304_120140_11376.jpg
#   inflating: data/valid/Patanella/20130307_093806_50880.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130307_093806_50880.jpg
#   inflating: data/valid/Patanella/20130305_054402_05971.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_054402_05971.jpg
#   inflating: data/valid/Patanella/20130304_110644_01642.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130304_110644_01642.jpg
#   inflating: data/valid/Patanella/20130307_083520_37026.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130307_083520_37026.jpg
#   inflating: data/valid/Patanella/20130410_084913_46383.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130410_084913_46383.jpg
#   inflating: data/valid/Patanella/20130305_120910_73179.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_120910_73179.jpg
#   inflating: data/valid/Patanella/20130305_075713_31002.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_075713_31002.jpg
#   inflating: data/valid/Patanella/20130305_081121_33100.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130305_081121_33100.jpg
#   inflating: data/valid/Patanella/20130306_141509_79682.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130306_141509_79682.jpg
#   inflating: data/valid/Patanella/20130304_145155_40899.jpg
#   inflating: __MACOSX/data/valid/Patanella/._20130304_145155_40899.jpg
# ...
#   inflating: __MACOSX/data/train/Barchino/._20130305_140612_89584.jpg
#   inflating: data/train/Barchino/20130307_080626_32198.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_080626_32198.jpg
#   inflating: data/train/Barchino/20130305_160229_04609.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_160229_04609.jpg
#   inflating: data/train/Barchino/20130410_110128_71665.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_110128_71665.jpg
#   inflating: data/train/Barchino/20130410_090820_50975.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_090820_50975.jpg
#   inflating: data/train/Barchino/20130305_160658_05431.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_160658_05431.jpg
#   inflating: data/train/Barchino/20130306_084943_32747.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_084943_32747.jpg
#   inflating: data/train/Barchino/20130304_081021_30544.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_081021_30544.jpg
#   inflating: data/train/Barchino/20130305_073913_27463.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_073913_27463.jpg
#   inflating: data/train/Barchino/20130307_123250_80561.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_123250_80561.jpg
#   inflating: data/train/Barchino/20130306_112928_58057.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_112928_58057.jpg
#   inflating: data/train/Barchino/20130410_101338_63346.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_101338_63346.jpg
#   inflating: data/train/Barchino/20130304_151342_44038.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_151342_44038.jpg
#   inflating: data/train/Barchino/20130306_112542_57655.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_112542_57655.jpg
#   inflating: data/train/Barchino/20130305_150033_96587.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_150033_96587.jpg
#   inflating: data/train/Barchino/20130305_152256_99517.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_152256_99517.jpg
#   inflating: data/train/Barchino/20130305_111335_64560.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_111335_64560.jpg
#   inflating: data/train/Barchino/20130304_153243_47442.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_153243_47442.jpg
#   inflating: data/train/Barchino/20130304_084601_38273.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_084601_38273.jpg
#   inflating: data/train/Barchino/20130305_122838_76612.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_122838_76612.jpg
#   inflating: data/train/Barchino/20130307_111718_69583.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_111718_69583.jpg
#   inflating: data/train/Barchino/20130307_085830_41871.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_085830_41871.jpg
#   inflating: data/train/Barchino/20130410_081047_36787.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_081047_36787.jpg
#   inflating: data/train/Barchino/20130304_161116_52771.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_161116_52771.jpg
#   inflating: data/train/Barchino/20130305_165423_11424.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_165423_11424.jpg
#   inflating: data/train/Barchino/20130307_094258_51844.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_094258_51844.jpg
#   inflating: data/train/Barchino/20130304_081025_30577.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_081025_30577.jpg
#   inflating: data/train/Barchino/20130304_080553_29871.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_080553_29871.jpg
#   inflating: data/train/Barchino/20130304_142335_35277.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_142335_35277.jpg
#   inflating: data/train/Barchino/20130306_071512_16132.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_071512_16132.jpg
#   inflating: data/train/Barchino/20130410_112611_76901.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_112611_76901.jpg
#   inflating: data/train/Barchino/20130304_142333_35266.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_142333_35266.jpg
#   inflating: data/train/Barchino/20130304_170106_59590.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_170106_59590.jpg
#   inflating: data/train/Barchino/20130410_151329_18392.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_151329_18392.jpg
#   inflating: data/train/Barchino/20130306_073836_20371.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_073836_20371.jpg
#   inflating: data/train/Barchino/20130307_072452_23250.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_072452_23250.jpg
#   inflating: data/train/Barchino/20130307_082728_35772.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_082728_35772.jpg
#   inflating: data/train/Barchino/20130304_145826_42040.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_145826_42040.jpg
#   inflating: data/train/Barchino/20130305_152259_99521.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_152259_99521.jpg
#   inflating: data/train/Barchino/20130305_114530_69047.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_114530_69047.jpg
#   inflating: data/train/Barchino/20130410_154244_22510.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_154244_22510.jpg
#   inflating: data/train/Barchino/20130304_145147_40831.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_145147_40831.jpg
#   inflating: data/train/Barchino/20130304_074602_25752.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_074602_25752.jpg
#   inflating: data/train/Barchino/20130304_144159_39015.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_144159_39015.jpg
#   inflating: data/train/Barchino/20130305_162659_08269.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_162659_08269.jpg
#   inflating: data/train/Barchino/20130306_093008_39802.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_093008_39802.jpg
#   inflating: data/train/Barchino/20130305_092359_44749.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_092359_44749.jpg
#   inflating: data/train/Barchino/20130410_154756_23562.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_154756_23562.jpg
#   inflating: data/train/Barchino/20130305_163452_08865.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_163452_08865.jpg
#   inflating: data/train/Barchino/20130410_092026_53335.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_092026_53335.jpg
#   inflating: data/train/Barchino/20130306_134826_76021.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_134826_76021.jpg
#   inflating: data/train/Barchino/20130305_141413_90561.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_141413_90561.jpg
#   inflating: data/train/Barchino/20130410_160014_25844.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_160014_25844.jpg
#   inflating: data/train/Barchino/20130304_165956_59445.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_165956_59445.jpg
#   inflating: data/train/Barchino/20130307_145845_00315.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_145845_00315.jpg
#   inflating: data/train/Barchino/20130304_082648_34430.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_082648_34430.jpg
#   inflating: data/train/Barchino/20130305_093748_46935.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_093748_46935.jpg
#   inflating: data/train/Barchino/20130304_170108_59619.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_170108_59619.jpg
#   inflating: data/train/Barchino/20130410_155346_24232.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_155346_24232.jpg
#   inflating: data/train/Barchino/20130304_140955_33241.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_140955_33241.jpg
#   inflating: data/train/Barchino/20130304_084533_38183.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_084533_38183.jpg
#   inflating: data/train/Barchino/20130304_143313_36931.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_143313_36931.jpg
#   inflating: data/train/Barchino/20130306_074111_20802.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_074111_20802.jpg
#   inflating: data/train/Barchino/20130410_100704_62186.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_100704_62186.jpg
#   inflating: data/train/Barchino/20130304_155259_50213.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_155259_50213.jpg
#   inflating: data/train/Barchino/20130305_162413_07988.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_162413_07988.jpg
#   inflating: data/train/Barchino/20130304_160505_51230.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_160505_51230.jpg
#   inflating: data/train/Barchino/20130307_104319_63409.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_104319_63409.jpg
#   inflating: data/train/Barchino/20130304_161522_53235.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_161522_53235.jpg
#   inflating: data/train/Barchino/20130304_153151_47138.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_153151_47138.jpg
#   inflating: data/train/Barchino/20130305_093751_47033.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_093751_47033.jpg
#   inflating: data/train/Barchino/20130305_092400_44886.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_092400_44886.jpg
#   inflating: data/train/Barchino/20130304_072143_21529.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_072143_21529.jpg
#   inflating: data/train/Barchino/20130304_150413_42703.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_150413_42703.jpg
#   inflating: data/train/Barchino/20130410_164211_03532.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_164211_03532.jpg
#   inflating: data/train/Barchino/20130305_143948_94266.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_143948_94266.jpg
#   inflating: data/train/Barchino/20130305_135358_86286.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_135358_86286.jpg
#   inflating: data/train/Barchino/20130305_100216_51453.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_100216_51453.jpg
#   inflating: data/train/Barchino/20130304_154523_49077.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_154523_49077.jpg
#   inflating: data/train/Barchino/20130306_084946_32958.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_084946_32958.jpg
#   inflating: data/train/Barchino/20130304_171111_60943.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_171111_60943.jpg
#   inflating: data/train/Barchino/20130305_075450_30640.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_075450_30640.jpg
#   inflating: data/train/Barchino/20130304_073413_23764.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_073413_23764.jpg
#   inflating: data/train/Barchino/20130305_113648_67792.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_113648_67792.jpg
#   inflating: data/train/Barchino/20130410_113959_79253.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_113959_79253.jpg
#   inflating: data/train/Barchino/20130304_155812_50679.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_155812_50679.jpg
#   inflating: data/train/Barchino/20130307_153040_04544.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_153040_04544.jpg
#   inflating: data/train/Barchino/20130305_084358_38706.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_084358_38706.jpg
#   inflating: data/train/Barchino/20130410_132955_01169.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_132955_01169.jpg
#   inflating: data/train/Barchino/20130304_082759_34839.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_082759_34839.jpg
#   inflating: data/train/Barchino/20130305_073915_27325.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_073915_27325.jpg
#   inflating: data/train/Barchino/20130304_072756_22929.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_072756_22929.jpg
#   inflating: data/train/Barchino/20130305_160408_04882.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_160408_04882.jpg
#   inflating: data/train/Barchino/20130305_081323_33210.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_081323_33210.jpg
#   inflating: data/train/Barchino/20130307_094255_51753.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_094255_51753.jpg
#   inflating: data/train/Barchino/20130305_112520_66215.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_112520_66215.jpg
#   inflating: data/train/Barchino/20130305_105353_59838.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_105353_59838.jpg
#   inflating: data/train/Barchino/20130306_121038_63939.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_121038_63939.jpg
#   inflating: data/train/Barchino/20130304_165137_58704.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_165137_58704.jpg
#   inflating: __MACOSX/data/train/._Barchino
#    creating: data/train/Motopontonerettangolare/
#   inflating: data/train/Motopontonerettangolare/20130410_125016_93082.jpg
#    creating: __MACOSX/data/train/Motopontonerettangolare/
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_125016_93082.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_134754_85449.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_134754_85449.jpg
#   inflating: data/train/Motopontonerettangolare/20130307_090745_43571.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130307_090745_43571.jpg
#   inflating: data/train/Motopontonerettangolare/20130306_062340_06111.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130306_062340_06111.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_062328_12371.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_062328_12371.jpg
#   inflating: data/train/Motopontonerettangolare/20130307_061609_10266.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130307_061609_10266.jpg
#   inflating: data/train/Motopontonerettangolare/20130306_104651_52563.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130306_104651_52563.jpg
#   inflating: data/train/Motopontonerettangolare/20130410_094753_59078.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_094753_59078.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_134752_85443.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_134752_85443.jpg
#   inflating: data/train/Motopontonerettangolare/20130307_061605_10139.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130307_061605_10139.jpg
#   inflating: data/train/Motopontonerettangolare/20130410_125013_93057.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_125013_93057.jpg
#   inflating: data/train/Motopontonerettangolare/20130304_063820_11725.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130304_063820_11725.jpg
#   inflating: data/train/Motopontonerettangolare/20130304_134311_29014.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130304_134311_29014.jpg
#   inflating: data/train/Motopontonerettangolare/20130306_135225_76614.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130306_135225_76614.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_105922_61080.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_105922_61080.jpg
#   inflating: data/train/Motopontonerettangolare/20130410_051903_01754.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_051903_01754.jpg
#   inflating: __MACOSX/data/train/._Motopontonerettangolare
#   inflating: __MACOSX/data/._train

# %% [markdown]
# We'll start by exploring the data, and look at how we can get that data loaded into memory through python code. We can just use the `ls` command from with this notebook to explore the data set:

# %%
# !ls data
# !ls data/test
# Out:
# mf.jpg	README.md  test  train	valid
# Alilaguna  Lanciafino10m	    Mototopo	     Sandoloaremi
# Ambulanza  Motobarca		    Patanella	     Topa
# Barchino   Motopontonerettangolare  Polizia	     VaporettoACTV
# Gondola    MotoscafoACTV	    Raccoltarifiuti  Water

# %% [markdown]
# If you explore the `data` directory you should see three folders:
#
# 	- The `train` folder contains the training data & is broken into subdirectories for each class.
# 	- The `valid` folder contains the validation data & is broken into subdirectories for each class.
# 	- The `test` folder contains the testing data & is broken into subdirectories for each class.
#
# The following displays one of the images:

# %%
from IPython.display import Image
Image("data/test/Alilaguna/20130412_064059_20202.jpg")

# %% [markdown]
# The `torchvision` library has support for directly reading images from a directory structure like the one we have using the `torchvision.datasets.ImageFolder` class. In addition to loading the images directly, `torchvision` provides a mechanism to dynamically augment the data being read by applying random transformations (flipping, rotating, etc), as well as cropping and scaling the images. The following code will generate a visualisation of the first batch of images produced by the data loader:

# %%
# %matplotlib inline

# Plot ad hoc data instances
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import transforms 
import matplotlib
import matplotlib.pyplot as plt
import numpy

transform = transforms.Compose([
    transforms.Resize((240, 800)),
    transforms.ToTensor()  # convert to tensor
])

train_dataset = ImageFolder("data/train", transform)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# generate the first batch
(batch_images, batch_labels) = train_loader.__iter__().__next__()

# plot 4 images
plt.subplot(221).set_title(train_dataset.classes[batch_labels[0]])
plt.imshow(batch_images[0].permute(1, 2, 0), aspect='equal')
plt.subplot(222).set_title(train_dataset.classes[batch_labels[1]])
plt.imshow(batch_images[1].permute(1, 2, 0), aspect='equal')
plt.subplot(223).set_title(train_dataset.classes[batch_labels[2]])
plt.imshow(batch_images[2].permute(1, 2, 0), aspect='equal')
plt.subplot(224).set_title(train_dataset.classes[batch_labels[3]])
plt.imshow(batch_images[3].permute(1, 2, 0), aspect='equal')

# show the plot
plt.show()

# %% [markdown]
# ## A simple CNN for boat classification
#
# Now let's try something a little more challenging and take our `BetterCNN` convolutional network from the experiments with mnist last week, and apply it to the problem of boat classification. Firstly we need to setup the data for training, and it would also be sensible to load the validation data to monitor performance during training, as well as load the test data:

# %%
# the number of images that will be processed in a single step
batch_size=128
# the size of the images that we'll learn on - we'll shrink them from the original size for speed
image_size=(30, 100)

transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor()  # convert to tensor
])

train_dataset = ImageFolder("data/train", transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageFolder("data/valid", transform)
val_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = ImageFolder("data/test", transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Note that for now we're not using any data augmentation from the training data, however we've structured the code so that we can easily add it by manipulating the transforms that are applied. Note that if we dot that, we probably wouldn't want to do the augmentation of the validation/test sets, so we would need a separate set of transforms for those.
#
# Now we can add the network definition from last week. We'll make a slight change to the previous `BetterCNN` function so that it allows us to specify the number of input channels and the number of output classes in the constructor. In the following block you'll need to paste your implementation of the `BetterCNN` forward method from last week:

# %%
import torch 
import torch.nn.functional as F
from torch import nn

# Model Definition
class BetterCNN(nn.Module):
    def __init__(self, n_channels_in, n_classes):
        super(BetterCNN, self).__init__()
        self.conv1 = nn.Conv2d(n_channels_in, 30, (5, 5), padding=0)
        self.conv2 = nn.Conv2d(30, 15, (3, 3), padding=0)
        self.fc1 = nn.Linear(1725, 128)
        self.fc2 = nn.Linear(128, 50)
        self.fc3 = nn.Linear(50, n_classes)
    
    def forward(self, x):
        # YOUR CODE HERE
        out = self.conv1(x)
        out = F.relu(out)
        out = F.max_pool2d(out, (2,2))
        out = self.conv2(out)
        out = F.relu(out)
        out = F.max_pool2d(out, (2,2))
        out = F.dropout(out, 0.2)
        out = out.view(out.shape[0], -1)
        out = self.fc1(out)
        out = F.relu(out)
        out = self.fc2(out)
        out = F.relu(out)
        out = self.fc3(out)
        
        return out

# %% [markdown]
# We're now in a position to add the code to fit the model - we'll use `torchbearer` to help us out:

# %%
import torchbearer
from torchbearer import Trial
from torch import optim

model = BetterCNN(3, len(train_dataset.classes))

# define the loss function and the optimiser
loss_function = nn.CrossEntropyLoss()
optimiser = optim.Adam(model.parameters())

device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy']).to(device)
trial.with_generators(train_loader, val_generator=val_loader, test_generator=test_loader)
trial.run(epochs=10)
results = trial.evaluate(data_key=torchbearer.VALIDATION_DATA)
results_test = trial.evaluate(data_key=torchbearer.TEST_DATA)
print()
print(results)
print(results_test)
# Out:
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/1(e)', max=28, style=ProgressStyle(description_width='initi…
# {'val_loss': 0.819905698299408, 'val_acc': 0.7466897368431091}

# %% [markdown]
# Once the model is trained, we can investigate the performance on the test data. Rather than just look at the average accuracy we need to dig into a little more detail, so we'll use the `classification_report` method in scikit-learn to compute per-class precision and recall values:

# %%
predictions = trial.predict()
predicted_classes = predictions.argmax(1).cpu()
true_classes = list(x for (_,x) in test_dataset.samples)

from sklearn import metrics
print(metrics.classification_report(true_classes, predicted_classes, target_names=train_dataset.classes))
# Out:
# HBox(children=(IntProgress(value=0, description='0/1(p)', max=11, style=ProgressStyle(description_width='initi…
#                          precision    recall  f1-score   support
#
#               Alilaguna       0.39      0.68      0.50        19
#               Ambulanza       0.05      0.05      0.05        22
#                Barchino       0.00      0.00      0.00        51
#                 Gondola       0.00      0.00      0.00         3
#           Lanciafino10m       0.00      0.00      0.00         7
#               Motobarca       0.20      0.15      0.17        59
# Motopontonerettangolare       0.00      0.00      0.00         3
#           MotoscafoACTV       0.00      0.00      0.00         1
#                Mototopo       0.62      0.82      0.71       274
#               Patanella       0.28      0.45      0.34        74
#                 Polizia       0.00      0.00      0.00        15
#         Raccoltarifiuti       0.00      0.00      0.00        19
#            Sandoloaremi       0.00      0.00      0.00         3
#                    Topa       0.00      0.00      0.00        29
#           VaporettoACTV       0.96      0.98      0.97       325
#                   Water       0.97      0.93      0.95       420
#
#               micro avg       0.75      0.75      0.75      1324
#               macro avg       0.22      0.25      0.23      1324
#            weighted avg       0.70      0.75      0.72      1324
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# In this particular case you should observe that the overall accuracies are a bit mixed; whist the average is high, it is clear that our model doesnt work well for some classes. Be aware though that we're using a relatively small set of both training and validation data, and that there is a very high bias in the class distribution which inevitably could lead to higher accuracies because of common classes. As we mentioned in the lab last week, this network architecture isn't any thing like one that has won the image classification challenges.

# %% [markdown]
# ## Using a better network model - transferring and finetuning a pretrained ResNet
#
# Training a network from scratch can be a lot of work. Is there some way we could take an existing network trained on some data with one set of labels, and adapt it to work on a different data set with different labels? Assuming that the inputs of the network are equivalent (for example, image with the same number of bands and size), then the answer is an emphatic yes! This process of "finetuning" a pre-trained network has become common-place as its much faster an easier than starting from scratch. This approach will also help us better work with the small amount of data that we have to train with.
#
# Let's try this in practice - we'll start by loading a pre-trained network architecture called a Deep Residual Network (or ResNet for short) that has been trained on the 1000-class ImageNet dataset. The ResNet architecture is very deep - it has many (in our case 50) convolutional layers and is currently one of the best performing architectures on the ImageNet challenge. The PyTorch model zoo contains code that implements the resnet50 architecture, and automatically downloads the pre-trained model weights. We'll start by using this to load the model and test it by classifying an image:

# %%
from torchvision.models import resnet50
from urllib.request import urlopen

imagenet_labels = urlopen("https://raw.githubusercontent.com/Lasagne/Recipes/master/examples/resnet50/imagenet_classes.txt").read().decode('utf-8').split("\n")

model = resnet50(pretrained=True)
model.eval()

preprocess_input = transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

from PIL import Image as PImage
img_path = 'data/mf.jpg'
img = PImage.open(img_path)

print(preprocess_input(img))
preds = model(preprocess_input(img).unsqueeze(0))

_, indexes = preds.topk(5)
for i in indexes[0]:
    print('Predicted:', imagenet_labels[i])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 102502400it [00:01, 92180987.55it/s]
# tensor([[[ 0.7762,  0.7762,  0.7762,  ...,  0.6734,  0.6734,  0.6734],
#          [ 0.8104,  0.8104,  0.8104,  ...,  0.7248,  0.7248,  0.7077],
#          [ 0.8104,  0.8276,  0.8276,  ...,  0.7933,  0.7762,  0.7419],
#          ...,
#          [-1.4500, -1.1418, -1.3302,  ..., -0.9705,  0.1426,  0.0227],
#          [-1.4843, -1.5357, -1.5528,  ..., -0.3369, -0.3541, -0.4226],
#          [-1.6555, -1.8097, -1.5699,  ..., -0.0287, -0.5082, -0.6794]],
#
#         [[ 0.9230,  0.9230,  0.9230,  ...,  0.8354,  0.8354,  0.8354],
#          [ 0.9580,  0.9580,  0.9580,  ...,  0.8880,  0.8880,  0.8704],
#          [ 0.9580,  0.9755,  0.9755,  ...,  0.9580,  0.9405,  0.9055],
#          ...,
#          [-1.5630, -1.2829, -1.4230,  ..., -1.2479, -0.1275, -0.3200],
#          [-1.5805, -1.6681, -1.6331,  ..., -0.5476, -0.6001, -0.7402],
#          [-1.7556, -1.9132, -1.6155,  ..., -0.2500, -0.7752, -0.9328]],
#
#         [[ 1.1759,  1.1759,  1.1759,  ...,  1.1237,  1.1237,  1.1237],
#          [ 1.2108,  1.2108,  1.2108,  ...,  1.1759,  1.1759,  1.1585],
#          [ 1.2108,  1.2282,  1.2282,  ...,  1.2457,  1.2282,  1.1934],
#          ...,
#          [-1.5256, -1.2293, -1.3164,  ..., -1.2293, -0.3578, -0.4798],
#          [-1.4907, -1.5430, -1.4907,  ..., -0.6890, -0.8458, -0.8807],
#          [-1.5953, -1.7347, -1.4733,  ..., -0.5670, -0.9678, -1.0027]]])
# Predicted: barracouta, snoek
# Predicted: gar, garfish, garpike, billfish, Lepisosteus osseus
# Predicted: coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch
# Predicted: sturgeon
# Predicted: great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias

# %% [markdown]
# If you run the above code (it will take a little longer the first time as the model is downloaded), it should indicate that our input image was likely to contain a fish! Run the following block to display the image and verify this.
#
# The `preprocess_input` transformation in the above is important - it's responsible for applying the same normalisation operations to our input image as were applied to the images when the network was trained, as well as getting the image to the 224x224 size expected by the network.

# %%
Image("data/mf.jpg")

# %% [markdown]
# In the above code to load the pretrained ResNet model, after the model is loaded we call `model.eval()`. Why is this? What happens if you don't make this call before using the model? __Write your answers in the following block:__

# %% [markdown]
# We need to choose a propriate pretrained model to use on the problem we are facing. If we use a pretrained model which is used in different situation, it will lead to a huge error. Thus we need to call `model.eval()` to test the pretraind model.

# %% [markdown]
# We're now in a position to start to hack the model structure. Fundamentally we need to first remove the classification layer at the end of the model and replace it with a new one (with a different number of classes). Let's print out the model structure:

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# Looking at the model we can see that really what we want to do is just replace the last fully connected layer with one with a different number of features. There are many ways in which PyTorch allows us to do this, but the simplest is to just do a direct replacement.
#
# We'll also make a small change to the pooling layer before the last fully connected layer; in the default ResNet model 2D average pooling is used to reduce a 2048x7x7 tensor to 2048x1x1 by using a 7x7 pooling window. This is precisely the definition of Global Average Pooling, however it is implemented with a fixed size window. As our boat images are not square, it would be nice if we could use them at a high resolution without cropping. We can replace the pooling layer with an `nn.AdaptiveAvgPool2d` layer that will perform real Global Average Pooling by dynamically scaling the window to whatever spatial size the input feature maps have:

# %%
model = resnet50(pretrained=True)
model.avgpool = nn.AdaptiveAvgPool2d((1,1))
model.fc = nn.Linear(2048, len(train_dataset.classes))
model.train()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=16, bias=True)
# )

# %% [markdown]
# The actual process of finetuning involves us now training the model with our own data. As the network is already largely trained, we'll likely want to use a small learning rate so not to make big changes in weights. Often we'll first "freeze" the weights of the already trained layers whilst we learn initial weights for our new layer to avoid overfitting while training:

# %%
# for param in model.layer1.parameters():
#   param.requires_grad = False
# for param in model.layer2.parameter2():
#   param.requires_grad = False

# %%
# Freeze layers by not tracking gradients
for param in model.parameters():
    param.requires_grad = False
model.fc.weight.requires_grad = True #unfreeze last layer weights
model.fc.bias.requires_grad = True #unfreeze last layer biases

optimiser = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3) #only optimse non-frozen layers

# %% [markdown]
# If we have lots of training data we could then unlock these layers and perform end-to-end finetuning afterwards. The Standford CS231n course pages have lots of useful hints on fine-tuning: http://cs231n.github.io/transfer-learning/
#
# __Use the following block to try finetuning the resnet50 with the boat data. You'll need a GPU to do this effectively as it's _rather_ slow!__

# %%
# YOUR CODE HERE
loss_function = nn.CrossEntropyLoss()

device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy']).to(device)
trial.with_generators(train_loader, val_generator=val_loader, test_generator=test_loader)
trial.run(epochs=10)
results = trial.evaluate(data_key=torchbearer.VALIDATION_DATA)
results_test = trial.evaluate(data_key=torchbearer.TEST_DATA)
print()
print(results)
print(results_test)
# Out:
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/1(e)', max=28, style=ProgressStyle(description_width='initi…
# {'val_loss': 0.4025937616825104, 'val_acc': 0.8664364218711853}

# %%
model2 = resnet50(pretrained=True)
model2.eval()

preprocess_input = transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

model2 = resnet50(pretrained=True)
model2.avgpool = nn.AdaptiveAvgPool2d((1,1))
model2.fc = nn.Linear(2048, len(train_dataset.classes))
model2.train()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=16, bias=True)
# )

# %%
for param in model2.layer1.parameters():
  param.requires_grad = False
for param in model2.layer2.parameters():
  param.requires_grad = False
  
optimiser2 = optim.Adam(filter(lambda p: p.requires_grad, model2.parameters()), lr=1e-3)

# %%
trial = Trial(model2, optimiser2, loss_function, metrics=['loss', 'accuracy']).to(device)
trial.with_generators(train_loader, val_generator=val_loader, test_generator=test_loader)
trial.run(epochs=10)
results = trial.evaluate(data_key=torchbearer.VALIDATION_DATA)
results_test = trial.evaluate(data_key=torchbearer.TEST_DATA)
print()
print(results)
print(results_test)
# Out:
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/1(e)', max=28, style=ProgressStyle(description_width='initi…
# {'val_loss': 0.20879429578781128, 'val_acc': 0.9306275248527527}

# %% [markdown]
# Use the following block to note down the performance you achieve by finetuning the model. How does this compare to the `BetterCNN` model used earlier?

# %% [markdown]
# The accuracy score after finetuning is lower than BetterCNN model.

# %% [markdown]
# ## Extracting features from a model
#
# Sometimes you want to do things that are not so easily accomplished with a deep network. You might want to build classifiers using very small amounts of data, or you might want a way of finding things in photographs that are in some way semantically similar, but don't have exactly the same classes. CNNs can actually help here using a technique known often called transfer learning (and related to the fine tuning that we just looked at). If we assume we have a trained network, then by extracting vectors from the layers before the final classifier we should have a means of achieving these tasks, as the vectors are likely to strongly encode semantic information about the content of the input image. If we wanted to quickly train new classifiers for new classes, we could for instance just use a relatively simple linear classifier trained on these vectors. If we wanted to find semantically similar images, we could just compare the Euclidean distance of these vectors.
#
# PyTorch makes it pretty easy to get these vector representations. The following code gets a resnet model in which the a feature vector is computed from the penultimate layer of the network by applying a _global average pooling_ operation over the feature maps:

# %%
from torch import nn
model = resnet50(pretrained=True)
feature_extractor_model = nn.Sequential(*list(model.children())[:-2], nn.AdaptiveAvgPool2d((1,1)))
feature_extractor_model.eval()
feature_extractor_model = feature_extractor_model.to(device)

# %% [markdown]
# With this model, extract the features for some inputs. To demonstrate, we can put the whole thing together and generate a vector from an image:

# %%
transform = transforms.Compose([
    transforms.Resize((240, 800)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                          std=[0.229, 0.224, 0.225]),
])

img_path = 'data/test/Alilaguna/20130412_064059_20202.jpg'
img = PImage.open(img_path)
feature = feature_extractor_model(preprocess_input(img).unsqueeze(0).to(device))
print('Feature shape:', feature.shape)
print('Feature data:', feature[0].reshape(-1))
# Out:
# Feature shape: torch.Size([1, 2048, 1, 1])
# Feature data: tensor([0.2288, 0.6563, 0.0540,  ..., 0.0110, 0.6035, 0.1322], device='cuda:0',
#        grad_fn=<AsStridedBackward>)

# %% [markdown]
# Use the following block to generate some features for some different images in the test set, and calculate the Euclidean distances between these features.

# %%
# YOUR CODE HERE
img_2_path = 'data/test/Alilaguna/20130412_084027_47543.jpg'
img_2 = PImage.open(img_2_path)
feature_2 = feature_extractor_model(preprocess_input(img_2).unsqueeze(0).to(device))

img_3_path = 'data/test/Motobarca/20130412_043117_54573.jpg'
img_3 = PImage.open(img_3_path)
feature_3 = feature_extractor_model(preprocess_input(img_3).unsqueeze(0).to(device))

eu_dist = nn.PairwiseDistance(p=2.0, eps=1e-06, keepdim=False)
distance_1_2 = eu_dist(feature, feature_2)
distance_1_3 = eu_dist(feature, feature_3)
distance_2_3 = eu_dist(feature_2, feature_3)
print(distance_1_2, '\n', distance_1_3, '\n', distance_2_3)
# Out:
# tensor([[[10.4371]]], device='cuda:0', grad_fn=<NormBackward1>)
#  tensor([[[21.3633]]], device='cuda:0', grad_fn=<NormBackward1>)
#  tensor([[[18.8967]]], device='cuda:0', grad_fn=<NormBackward1>)

# %%
Image(img_path)

# %%
Image(img_2_path)

# %%
Image(img_3_path)

# %% [markdown]
# In the following block describe how the Euclidean distances compare to your perception of similarity between the images:

# %% [markdown]
# The more similarities they have, the smaller the distance is.

# %% [markdown]
# Let's now explore how features from a ResNet could be used with a classifier that works well with small amounts of training data - a Support Vector Machine. Use the following block to train a multiclass SVM using the `sklearn.svm.SVC` class to learn the boat classes using the features extracted by the ResNet50 with the default imagenet weights. Once you've trained it (and optimised the parameters) print out a classification report.
#
# We've provided all the features and labels in the form of `numpy` arrays so you don't have to extract them (which can take a few minutes; you can view the code we used [here](https://github.com/ecs-vlc/COMP6248/blob/master/docs/labs/lab6/genfeats.py)):

# %%
import numpy as np

if not exists('training_features.npy'):
    # !wget -O Resnet50Features.zip http://www.southampton.ac.uk/~jsh2/comp6248-lab-data/Resnet50Features.zip
    # !unzip Resnet50Features.zip

training_features = np.load('training_features.npy')
training_labels = np.load('training_labels.npy')

valid_features = np.load('valid_features.npy')
valid_labels = np.load('valid_labels.npy')

testing_features = np.load('testing_features.npy')
testing_labels = np.load('testing_labels.npy')

# %%
# YOUR CODE HERE
from sklearn.svm import SVC

clf = SVC(gamma='auto')
clf.fit(training_features, training_labels)
predicted_classes = clf.predict(testing_features)
true_classes = testing_labels
accuracy_score = clf.score(testing_features, testing_labels)
print('test_score:', accuracy_score)


from sklearn import metrics
print(metrics.classification_report(true_classes, predicted_classes, target_names=train_dataset.classes))
# Out:
# test_score: 0.7613293051359517
#                          precision    recall  f1-score   support
#
#               Alilaguna       0.00      0.00      0.00        19
#               Ambulanza       0.00      0.00      0.00        22
#                Barchino       0.00      0.00      0.00        51
#                 Gondola       0.00      0.00      0.00         3
#           Lanciafino10m       0.00      0.00      0.00         7
#               Motobarca       0.00      0.00      0.00        59
# Motopontonerettangolare       0.00      0.00      0.00         3
#           MotoscafoACTV       0.00      0.00      0.00         1
#                Mototopo       0.50      1.00      0.67       274
#               Patanella       0.31      0.23      0.27        74
#                 Polizia       0.00      0.00      0.00        15
#         Raccoltarifiuti       0.00      0.00      0.00        19
#            Sandoloaremi       0.00      0.00      0.00         3
#                    Topa       0.00      0.00      0.00        29
#           VaporettoACTV       0.99      1.00      0.99       325
#                   Water       0.98      0.94      0.96       420
#
#               micro avg       0.76      0.76      0.76      1324
#               macro avg       0.17      0.20      0.18      1324
#            weighted avg       0.68      0.76      0.70      1324
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Use the following block to reflect on how the test performance compares to the finetuned ResNet. What is the difference in time taken to train and evaluate the different approaches?

# %% [markdown]
# The performance of  finetuned ResNet model is much better than the SVM. But the SVM model takes less time.
#
# ---
